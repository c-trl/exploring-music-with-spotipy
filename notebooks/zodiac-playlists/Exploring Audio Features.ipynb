# %% [markdown]
# # According to <a href='https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/'>Spotify Documentation</a>
#
# **Acousticness** is a confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# **Danceability** describes how suitable a track is for dancing based on a combination of musical elements including **tempo**, **rhythm stability**, **beat strength**, and **overall regularity**. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# **Energy** is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel **fast**, **loud**, and **noisy**. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# **Instrumentalness** predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. **Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0**.
#
# **Key** is the estimated overall key of the track. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
#
# **Liveness** detects the presence of an audience in the recording. Higher liveness values represent an increased **probability that the track was performed live**. A value above 0.8 provides strong likelihood that the track is live
#
# **Tempo** is the overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the **speed or pace** of a given piece and derives directly from the average beat duration.
#
# **Valence** is a measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. **happy**, **cheerful**, **euphoric**), while tracks with low valence sound more negative (e.g. **sad**, **depressed**, **angry**).

# %%
import pandas as pd

df = pd.read_csv('spotify_track_with_genres.csv')

# %%
df = df[['playlist_name','track_name','track_popularity','added_on','danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','track_artist', 'time_added', 'date_added', 'hour_added']]

# %%
# adding an order number to each playlist for numeric plotting below

# %%
df = df.merge(pd.DataFrame([i for i in enumerate(df.sort_values(by='added_on',ascending=True).playlist_name.unique())]).rename(columns={0:'playlist_order',1:'playlist_name'}),on='playlist_name')

# %%
df[df.energy / df.danceability > 2.5] #these songs have relatively high "energy" compared to danceability
# Out:
#     playlist_name       track_name  track_popularity              added_on  \
# 14    Acquiesence         New Fang                54  2019-01-22T14:39:45Z
# 48    Acquiesence   Flagpole Sitta                61  2019-02-07T14:20:39Z
# 200      Vitamins  Speaking Gently                47  2018-08-22T16:31:51Z
# 206      Vitamins        Don't Cry                47  2018-08-23T07:57:55Z
# 445      Oftenlie    Born to Shine                39  2018-01-27T05:46:37Z
# 762     Vigilante          Spinner                27  2017-08-30T13:55:49Z
#
#      danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 14          0.276   0.962  11.0    -3.797   0.0       0.0629      0.000010
# 48          0.351   0.899   7.0    -4.119   1.0       0.0432      0.001840
# 200         0.325   0.834   5.0    -5.015   0.0       0.0411      0.000053
# 206         0.230   0.770   1.0    -6.349   1.0       0.3370      0.053500
# 445         0.355   0.892   7.0    -6.519   0.0       0.7010      0.019100
# 762         0.241   0.778   5.0    -6.057   0.0       0.0539      0.010300
#
#      instrumentalness  liveness  valence    tempo           track_artist  \
# 14           0.000366    0.0327    0.741  189.898  Them Crooked Vultures
# 48           0.000116    0.2840    0.508  145.015          Harvey Danger
# 200          0.838000    0.1120    0.511   78.198          BADBADNOTGOOD
# 206          0.000156    0.6440    0.588  173.442                J Dilla
# 445          0.000000    0.0857    0.302  152.849              Big Grams
# 762          0.934000    0.2260    0.519  198.229        Portico Quartet
#
#     time_added  date_added  hour_added
# 14    14:39:45  2019-01-22          14
# 48    14:20:39  2019-02-07          14
# 200   16:31:51  2018-08-22          16
# 206   07:57:55  2018-08-23           7
# 445   05:46:37  2018-01-27           5
# 762   13:55:49  2017-08-30          13

# %%
df[df.energy / df.danceability < 0.25] #these songs have relatively low "energy" compared to danceability
# Out:
#       playlist_name                                   track_name  \
# 166       Libations                                   Game over!
# 168       Libations                                       Jovial
# 175       Libations                                       Tulips
# 192       Libations                                    this girl
# 505          Capcom                                          6 8
# 644  Scorpion Gulch                                    patagonia
# 932        Aruarian  #LostScrolls 1 (Bonus Track) - Instrumental
#
#      track_popularity              added_on  danceability  energy   key  \
# 166                54  2018-09-27T00:46:03Z         0.635  0.0861  11.0
# 168                59  2018-09-28T04:49:32Z         0.764  0.1850   7.0
# 175                58  2018-10-01T19:27:51Z         0.835  0.1470   6.0
# 192                65  2018-10-10T00:05:49Z         0.788  0.1500   8.0
# 505                49  2017-12-26T09:42:03Z         0.824  0.1360   0.0
# 644                 0  2017-11-06T20:30:54Z         0.679  0.1330   8.0
# 932                 0  2017-02-13T23:39:18Z         0.828  0.1060   6.0
#
#      loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 166   -18.311   0.0       0.0755         0.358           0.00995    0.1380
# 168   -14.408   0.0       0.0489         0.918           0.92600    0.1180
# 175    -9.837   0.0       0.3410         0.854           0.88100    0.1110
# 192   -10.002   1.0       0.2470         0.895           0.87000    0.1010
# 505    -7.938   1.0       0.0588         0.894           0.00350    0.0765
# 644   -13.636   1.0       0.1350         0.932           0.75000    0.1040
# 932   -14.054   1.0       0.1320         0.392           0.99000    0.1100
#
#      valence    tempo            track_artist time_added  date_added  \
# 166   0.0618  130.146             Harris Cole   00:46:03  2018-09-27
# 168   0.3780   69.972                   Limes   04:49:32  2018-09-28
# 175   0.4690   84.048                   emune   19:27:51  2018-10-01
# 192   0.4640  139.983              Elijah Who   00:05:49  2018-10-10
# 505   0.1550  115.030  Gabriel Garzón-Montano   09:42:03  2017-12-26
# 644   0.6230   81.935                Bilo 503   20:30:54  2017-11-06
# 932   0.8020   95.466                 J Dilla   23:39:18  2017-02-13
#
#      hour_added
# 166           0
# 168           4
# 175          19
# 192           0
# 505           9
# 644          20
# 932          23

# %%
# %matplotlib inline

# %% [markdown]
# # By Hour Added
# ---

# %%
y = 'instrumentalness'
x = 'hour_added' #time of day

for y in ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']:
    df[[x,y]].plot(
        kind='scatter',
        y=y,
        x=x,
        figsize=(20,5),
        alpha=.05,
        c='lightskyblue',
        s=250,
        xticks=df[x],
        title=y.upper()
    )

    df[[x,y]].groupby(x).mean().reset_index().plot(
        kind='line',
        x=x,
        y=y,
        figsize=(20,5),
        xticks=df[x],
        title=y.upper()
    )
# Out:
# /Users/ctirol/miniconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# # By Playlist
# ---

# %%
y = 'instrumentalness'
x = 'playlist_order' #time of day

for y in ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']:
    df[[x,y]].plot(
        kind='scatter',
        y=y,
        x=x,
        figsize=(20,5),
        alpha=.05,
        c='lightskyblue',
        s=250,
        xticks=df[x],
        title=y.upper()
    )
'''
    df[[x,y]].groupby(x).mean().reset_index().plot(
        kind='line',
        x=x,
        y=y,
        figsize=(20,5),
#        xticks=df[x],
        title=y.upper()
    )
'''
# Out:
# "\n    df[[x,y]].groupby(x).mean().reset_index().plot(\n        kind='line',\n        x=x,\n        y=y,\n        figsize=(20,5),\n#        xticks=df[x],\n        title=y.upper()\n    )\n"

# %% [markdown]
# # Which artists are the happiest?
# ---

# %%
df.groupby('track_artist').mean().sort_values(by=['artist_popularity','track_popularity'],ascending=False).head()
# Out:
#               track_popularity  danceability  energy  key  loudness  mode  \
# track_artist
# Drake                     75.0         0.927   0.488  9.0    -9.433   0.0
# Post Malone               20.0         0.580   0.531  5.0    -6.631   0.0
# Travis Scott              85.0         0.841   0.728  7.0    -3.370   1.0
# Halsey                    59.0         0.444   0.470  0.0    -6.897   0.0
# Future                    31.0         0.833   0.434  2.0    -8.795   1.0
#
#               speechiness  acousticness  instrumentalness  liveness  valence  \
# track_artist
# Drake              0.4200        0.1080          0.000000    0.1960    0.605
# Post Malone        0.0776        0.1280          0.000127    0.1430    0.141
# Travis Scott       0.0484        0.0847          0.000000    0.1490    0.430
# Halsey             0.0611        0.6170          0.000000    0.0861    0.164
# Future             0.4310        0.0102          0.021900    0.1650    0.281
#
#                 tempo  duration_ms  time_signature  hour_added  day_added  \
# track_artist
# Drake         133.987     210937.0             4.0        19.0        6.0
# Post Malone   159.786     218320.0             4.0        21.0        6.0
# Travis Scott  130.049     243837.0             4.0         2.0        7.0
# Halsey         89.945     187241.0             4.0        14.0        7.0
# Future        150.062     204600.0             4.0         4.0        3.0
#
#               artist_popularity  artist_followers
# track_artist
# Drake                      97.0        33540761.0
# Post Malone                95.0        11355195.0
# Travis Scott               93.0         4794552.0
# Halsey                     90.0         5204513.0
# Future                     90.0         7621468.0

# %%
df.groupby('track_artist').mean().sort_values(by=['valence','energy'],ascending=False).head()
# Out:
#                          track_popularity  danceability  energy  key  \
# track_artist
# Lupe Fiasco                          56.0         0.790   0.762  6.0
# Ljones                               45.0         0.762   0.746  1.0
# Hypnotic Brass Ensemble               0.0         0.719   0.551  1.0
# Flight Facilities                    44.0         0.838   0.627  8.0
# Moses Boyd                           31.0         0.440   0.906  0.0
#
#                          loudness  mode  speechiness  acousticness  \
# track_artist
# Lupe Fiasco                -5.704   0.0       0.2430        0.0418
# Ljones                     -8.828   1.0       0.0392        0.1530
# Hypnotic Brass Ensemble    -9.822   1.0       0.1210        0.2370
# Flight Facilities          -8.415   0.0       0.0995        0.4150
# Moses Boyd                 -7.564   0.0       0.0507        0.2980
#
#                          instrumentalness  liveness  valence    tempo  \
# track_artist
# Lupe Fiasco                       0.00000    0.0870    0.960   75.549
# Ljones                            0.94400    0.1090    0.954   96.167
# Hypnotic Brass Ensemble           0.79300    0.1350    0.942   95.934
# Flight Facilities                 0.00251    0.8510    0.932  111.019
# Moses Boyd                        0.91300    0.0941    0.901  134.345
#
#                          duration_ms  time_signature  hour_added  day_added  \
# track_artist
# Lupe Fiasco                 274910.0             4.0         6.0        3.0
# Ljones                      219820.0             4.0        11.5        4.5
# Hypnotic Brass Ensemble     288526.0             4.0         0.0        5.0
# Flight Facilities           265013.0             4.0         4.0        6.0
# Moses Boyd                  266226.0             4.0        14.5        1.0
#
#                          artist_popularity  artist_followers
# Canxer Season II          56.259259      5.476801e+05     6.481481
# Pieces                    54.950000      1.953013e+05     2.425000
# Sanguine                  58.687500      9.269594e+05    11.718750
# Taurus Season             73.562500      3.491809e+06     4.843750
# Leonidas                  61.594595      4.940553e+05     7.432432
# Aruarian                  57.370370      4.154476e+05     2.333333
# Sage Mode                 57.553191      4.280285e+05    11.553191
# Liberation Zone           48.159420      6.467345e+04     9.739130
# Oftenlie                  59.451613      5.480640e+05     1.419355
# Vigilante                 53.480769      2.833147e+05     8.557692
# Libations                 57.971429      7.225176e+05     9.714286
# Pierce                    56.200000      1.021195e+06     2.000000
# Capricious                67.114286      2.039998e+06     6.342857
# Scorpion Gulch            55.054795      6.188440e+05    10.643836
# Gemini Schemin            61.656250      5.175851e+05     6.031250
# Scarbrother               64.486486      1.867625e+06    10.486486
# Acquiesence               55.489362      4.827052e+05     1.446809
# Capcom                    63.442623      1.237754e+06     5.508197
# Cancer Season             58.967742      4.445515e+05     6.741935
# Vitamins                  51.261905      9.871302e+04     8.523810
# ToReUp                    63.513514      1.044283e+06     4.648649

# %%
for y in ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence']:
    top_month = ', '.join(df.groupby('month_added').mean().sort_values(by=[y],ascending=False).reset_index().month_added[0:3].astype(str))
    top_playlist = ', '.join(df.groupby('playlist_name').mean().sort_values(by=[y],ascending=False).reset_index().playlist_name[0:3])
    print(y.capitalize() + '\n' + top_month + '\n' + top_playlist)
    print()
# Out:
# Danceability
# 5, 12, 1
# Taurus Season, Sanguine, Libations
#
# Energy
# 5, 3, 6
# Geronimojo, Pierce, Sanguine
#
# Key
# 10, 9, 12
# Libations, Sage Mode, Gemini Schemin
#
# Loudness
# 5, 6, 3
# Sanguine, Geronimojo, Canxer Season II
#
# Mode
# 6, 4, 12
# ToReUp, Scarbrother, Gemini Schemin
#
# Speechiness
# 5, 6, 3
# Canxer Season II, Taurus Season, Geronimojo
#
# Acousticness
# 10, 9, 6
# Libations, Scarbrother, Vitamins
#
# Instrumentalness
# 10, 9, 8
# Liberation Zone, Aruarian, Vigilante
#
# Liveness
# 7, 3, 11
# Canxer Season II, Actionary, Sanguine
#
# Valence
# 2, 5, 7
# Actionary, Geronimojo, Canxer Season II

# %%
df.sort_values(by='time_signature',ascending=True)[['playlist_name','track_name','time_signature']]
# Out:
#         playlist_name                                         track_name  \
# 762         Vigilante                                            Spinner
# 892    Gemini Schemin                                             OooWee
# 757         Vigilante                                       4096 Colours
# 727   Liberation Zone                                           Descenso
# 869    Gemini Schemin                                              Gross
# 642    Scorpion Gulch                                              Yours
# 641    Scorpion Gulch                                            Illshit
# 16        Acquiesence                                             OooWee
# 854     Cancer Season                                             OooWee
# 287        Geronimojo                       Anita (feat. T-Pain) - Remix
# 257  Canxer Season II                                        Basic Beach
# 575         Sage Mode                                     I'm Not Racist
# 299        Geronimojo                                          Meteorite
# 300        Geronimojo                                              Seeds
# 57         Capricious                The Whole World (feat. Killer Mike)
# 201          Vitamins                                            Breathe
# 371         Actionary                                Essence of Sapphire
# 305            ToReUp                                         Moon River
# 195         Libations                                         Slow Hours
# 420            Pieces                                        That's O.K.
# 125       Scarbrother                                         Slow Hours
# 884    Gemini Schemin                                      S on Ya Chest
# 606    Scorpion Gulch                                      Origin of Man
# 870    Gemini Schemin                                         Reflection
# 590         Sage Mode                                       20 Something
# 620    Scorpion Gulch                                          Lecko Mio
# 865    Gemini Schemin                                               Jazz
# 383         Actionary                                      Electric Feel
# 44        Acquiesence                                      Final Thought
# 89         Capricious     Symphony No. 3 in F Major, Op. 90: II. Andante
# ..                ...                                                ...
# 313            ToReUp                         Heart Don't Stand a Chance
# 314            ToReUp                             Spaceships & Woodgrain
# 315            ToReUp                                             LAUDER
# 316            ToReUp                                             Biking
# 317            ToReUp                                           D/vision
# 318            ToReUp       Shot You Down (feat. Jay Rock & ScHoolboy Q)
# 319            ToReUp                         These Words Are Everything
# 333            ToReUp                                           TED Talk
# 320            ToReUp                                         Bangladesh
# 321            ToReUp                First World Problemz / Nobody Carez
# 951          Aruarian                                            Alarmed
# 323            ToReUp  What They'll Say (feat. Gary Clark Jr, Maimoun...
# 331            ToReUp             Crew (feat. Brent Faiyaz & Shy Glizzy)
# 330            ToReUp                                         EdEddnEddy
# 322            ToReUp                                          Afrophunk
# 328            ToReUp        Wat's Wrong (feat. Zacari & Kendrick Lamar)
# 329            ToReUp                                        Hasta Luego
# 326            ToReUp                                         Oh Shit!!!
# 325            ToReUp                                           Confetti
# 324            ToReUp                                    Decemba (Remix)
# 327            ToReUp                                          Affection
# 767         Vigilante                                                XXX
# 898     Taurus Season                             All The Way Up (Remix)
# 950          Aruarian           Confessions Pt. II (feat. Colin Stetson)
# 881    Gemini Schemin                                 Party All the Time
# 273        Geronimojo                                            Bubblin
# 302            ToReUp                                      Enlightenment
# 206          Vitamins                                          Don't Cry
# 262  Canxer Season II                                      Daniels Bloom
# 669    Scorpion Gulch                                          Juss Good
#
#      time_signature
# 762             1.0
# 892             1.0
# 757             1.0
# 727             1.0
# 869             1.0
# 642             1.0
# 641             1.0
# 16              1.0
# 854             1.0
# 287             1.0
# 257             1.0
# 575             3.0
# 299             3.0
# 300             3.0
# 57              3.0
# 201             3.0
# 371             3.0
# 305             3.0
# 195             3.0
# 420             3.0
# 125             3.0
# 884             3.0
# 606             3.0
# 870             3.0
# 590             3.0
# 620             3.0
# 865             3.0
# 383             3.0
# 44              3.0
# 89              3.0
# ..              ...
# 313             4.0
# 314             4.0
# 315             4.0
# 316             4.0
# 317             4.0
# 318             4.0
# 319             4.0
# 333             4.0
# 320             4.0
# 321             4.0
# 951             4.0
# 323             4.0
# 331             4.0
# 330             4.0
# 322             4.0
# 328             4.0
# 329             4.0
# 326             4.0
# 325             4.0
# 324             4.0
# 327             4.0
# 767             5.0
# 898             5.0
# 950             5.0
# 881             5.0
# 273             5.0
# 302             5.0
# 206             5.0
# 262             5.0
# 669             5.0
#
# [952 rows x 3 columns]
