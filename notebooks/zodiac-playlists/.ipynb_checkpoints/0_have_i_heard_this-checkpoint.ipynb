# %%
import pandas as pd

# %%
df = pd.read_csv('spotify_track_with_genres.csv')

# %%
df[df['track_artist'].str.contains('Tet')]
# Out:
#                 playlist_id   playlist_name  \
# 876  2YD9V5U6sl3I1HBxkmDVKJ  Gemini Schemin
#
#                                           playlist_uri  \
# 876  spotify:user:125065858:playlist:2YD9V5U6sl3I1H...
#
#                    track_id       track_name  track_popularity  \
# 876  133Ua3dR8fOR8uP7adVcL4  Parallel Jalebi                 1
#
#                                 track_uri              added_on  danceability  \
# 876  spotify:track:133Ua3dR8fOR8uP7adVcL4  2017-06-12T01:48:04Z         0.653
#
#      energy  ...  track_artist               artist_id  featured_artists  \
# 876     0.7  ...      Four Tet  7Eu1txygG6nJttLHbZdQOh               NaN
#
#      time_added  date_added  hour_added  day_added  \
# 876    01:48:04  2017-06-12           1          1
#
#                                          artist_genres  artist_popularity  \
# 876  alternative dance, electronic, indietronica, i...               62.0
#
#     artist_followers
# 876         298291.0
#
# [1 rows x 36 columns]

# %%
df[df['track_name'].str.contains('Goodie')]
# Out:
#                playlist_id playlist_name  \
# 84  6Pqno6KO7pgS6NZg1MkhV8    Capricious
#
#                                          playlist_uri                track_id  \
# 84  spotify:user:125065858:playlist:6Pqno6KO7pgS6N...  297rZsBEjFw9d0Gl3iBLnd
#
#     track_name  track_popularity                             track_uri  \
# 84  Goodie Bag                72  spotify:track:297rZsBEjFw9d0Gl3iBLnd
#
#                 added_on  danceability  energy  ...  track_artist  \
# 84  2019-01-11T22:50:09Z         0.701   0.529  ...   Still Woozy
#
#                  artist_id  featured_artists  time_added  date_added  \
# 84  4iMO20EPodreIaEl8qW66y               NaN    22:50:09  2019-01-11
#
#     hour_added  day_added                                      artist_genres  \
# 84          22          5  alternative r&b, bedroom pop, indie r&b, vapor...
#
#     artist_popularity artist_followers
# 84               66.0          83195.0
#
# [1 rows x 36 columns]

# %%
import spotipy
from credentials import client_id, client_secret
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

scope = 'user-library-read'
username = 'Christian Tirol'

user = '125065858'

# %%
sp.search(q='roadhouse blues',type='track',market='US')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=roadhouse+blues&type=track&market=US&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6AFLOkpJjFF652jevcSOZX'},
#      'href': 'https://api.spotify.com/v1/albums/6AFLOkpJjFF652jevcSOZX',
#      'id': '6AFLOkpJjFF652jevcSOZX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/34b1c4afdd8e576fb048e9e6c900c6c9fe33ea76',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/f1c903cdd2529c86d7c37cc4df0254710cfce6d7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/b35e7aef3f80c659eddd45a47d94bb743383a722',
#        'width': 64}],
#      'name': 'Morrison Hotel',
#      'release_date': '1970-02-09',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6AFLOkpJjFF652jevcSOZX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'disc_number': 1,
#     'duration_ms': 243826,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE19900375'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Q5kgpp4pmyGqPwNBzkSrw'},
#     'href': 'https://api.spotify.com/v1/tracks/1Q5kgpp4pmyGqPwNBzkSrw',
#     'id': '1Q5kgpp4pmyGqPwNBzkSrw',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Roadhouse Blues',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ce4e9952e1519b9fe6c858b085fbe79077ec9dfb?cid=dab7efda6fe0492cafb5ce82bb60351e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1Q5kgpp4pmyGqPwNBzkSrw'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3OIjlStgBVQfGjkiftDAZp'},
#      'href': 'https://api.spotify.com/v1/albums/3OIjlStgBVQfGjkiftDAZp',
#      'id': '3OIjlStgBVQfGjkiftDAZp',
#      'images': [{'height': 634,
#        'url': 'https://i.scdn.co/image/438a32a66412dac50b8c996cc622c08890488d9a',
#        'width': 640},
#       {'height': 297,
#        'url': 'https://i.scdn.co/image/4a2c2f923ff56da009819313d5ab2979021fd343',
#        'width': 300},
#       {'height': 63,
#        'url': 'https://i.scdn.co/image

#       'type': 'artist',
#       'uri': 'spotify:artist:5bHjVR4F2Tfq4Ha6x7K6wU'}],
#     'disc_number': 1,
#     'duration_ms': 145600,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEWC1790184'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2FfO6YoHCwUMM1j35F0Gwp'},
#     'href': 'https://api.spotify.com/v1/tracks/2FfO6YoHCwUMM1j35F0Gwp',
#     'id': '2FfO6YoHCwUMM1j35F0Gwp',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Roadhouse Blues',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/423b95d58c509bf7413bf444182265684a1003dd?cid=dab7efda6fe0492cafb5ce82bb60351e',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2FfO6YoHCwUMM1j35F0Gwp'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4YBBkcBOQi0kPcC89c3gof'},
#      'href': 'https://api.spotify.com/v1/albums/4YBBkcBOQi0kPcC89c3gof',
#      'id': '4YBBkcBOQi0kPcC89c3gof',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/c26353704b74bd3971a47063d46a85e4a81775b8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/66bf35630ee940b47fc4f70e33a578b874c21787',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/994d012e68e63bbf6a61b71dd52d03a9d9392cc8',
#        'width': 64}],
#      'name': 'Live At The Isle Of Wight Festival 1970',
#      'release_date': '2018-02-23',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4YBBkcBOQi0kPcC89c3gof'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'disc_number': 1,
#     'duration_ms': 309800,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCBR1700288'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0yfr07KdaN1xz3c0iXrVdo'},
#     'href': 'https://api.spotify.com/v1/tracks/0yfr07KdaN1xz3c0iXrVdo',
#     'id': '0yfr07KdaN1xz3c0iXrVdo',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Roadhouse Blues - Live At The Isle Of Wight Festival 1970',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0e3f12aa522ce5336880539ef52aba19afaa0ac8?cid=dab7efda6fe0492cafb5ce82bb60351e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0yfr07KdaN1xz3c0iXrVdo'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1YZiR5FINFOlZPGKSVplIY'},
#      'href': 'https://api.spotify.com/v1/albums/1YZiR5FINFOlZPGKSVplIY',
#      'id': '1YZiR5FINFOlZPGKSVplIY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/387d03c05bb0d7a201553de7e66b09600a69d2f8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/8b034b9c61d48a113b01df026d12287340319208',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/5062489905cb67e20db5893434c6b5c167b623e0',
#        'width': 64}],
#      'name': 'The Very Best Of The Doors',
#      'release_date': '2007-09-25',
#      'release_date_precision': 'day',
#      'total_tracks': 39,
#      'type': 'album',
#      'uri': 'spotify:album:1YZiR5FINFOlZPGKSVplIY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'disc_number': 1,
#     'duration_ms': 247466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10608669'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/672KpkAb0iQ5rfJyicnZ3h'},
#     'href': 'https://api.spotify.com/v1/tracks/672KpkAb0iQ5rfJyicnZ3h',
#     'id': '672KpkAb0iQ5rfJyicnZ3h',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Roadhouse Blues - New Stereo Mix; Advanced Resolution',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bbaf3cad9b09f3e69932ce9715f2efdbf800c3c6?cid=dab7efda6fe0492cafb5ce82bb60351e',
#     'track_number': 34,
#     'type': 'track',
#     'uri': 'spotify:track:672KpkAb0iQ5rfJyicnZ3h'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31z9f9AyPawiq0qlBO1M3i'},
#        'href': 'https://api.spotify.com/v1/artists/31z9f9AyPawiq0qlBO1M3i',
#        'id': '31z9f9AyPawiq0qlBO1M3i',
#        'name': 'Ryan Bingham',
#        'type': 'artist',
#        'uri': 'spotify:artist:31z9f9AyPawiq0qlBO1M3i'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2oLZMqHgX8H047wkXl23yC'},
#      'href': 'https://api.spotify.com/v1/albums/2oLZMqHgX8H047wkXl23yC',
#      'id': '2oLZMqHgX8H047wkXl23yC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/b63ca444702bc8154aa3464a17651c0aac9bd3c3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/8e5f869ccd5b6f89821518b680d43d6ebbb15792',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/d467aa82e03d02eeff832c0ac11c05f28cbf3a10',
#        'width': 64}],
#      'name': 'Roadhouse Sun',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2oLZMqHgX8H047wkXl23yC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31z9f9AyPawiq0qlBO1M3i'},
#       'href': 'https://api.spotify.com/v1/artists/31z9f9AyPawiq0qlBO1M3i',
#       'id': '31z9f9AyPawiq0qlBO1M3i',
#       'name': 'Ryan Bingham',
#       'type': 'artist',
#       'uri': 'spotify:artist:31z9f9AyPawiq0qlBO1M3i'}],
#     'disc_number': 1,
#     'duration_ms': 208733,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70954623'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0QOdIKSM3DIC3SBd0HbtM3'},
#     'href': 'https://api.spotify.com/v1/tracks/0QOdIKSM3DIC3SBd0HbtM3',
#     'id': '0QOdIKSM3DIC3SBd0HbtM3',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Roadhouse Blues',
#     'popularity': 21,
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:0QOdIKSM3DIC3SBd0HbtM3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aygfDCEaX5KTZOxSCpT9o'},
#        'href': 'https://api.spotify.com/v1/artists/5aygfDCEaX5KTZOxSCpT9o',
#        'id': '5aygfDCEaX5KTZOxSCpT9o',
#        'name': 'Albert King',
#        'type': 'artist',
#        'uri': 'spotify:artist:5aygfDCEaX5KTZOxSCpT9o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3kBahttJGSWR3pAmkGm6OR'},
#      'href': 'https://api.spotify.com/v1/albums/3kBahttJGSWR3pAmkGm6OR',
#      'id': '3kBahttJGSWR3pAmkGm6OR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/e8a44a14dad0d80260ee8b7c74deed53621b2bce',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/1d796dbed508c99db699731469ec97cb8c21721b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/64522489940be1fe2d32dcd2a8371346408137fb',
#        'width': 64}],
#      'name': 'Roadhouse Blues',
#      'release_date': '2013-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:3kBahttJGSWR3pAmkGm6OR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aygfDCEaX5KTZOxSCpT9o'},
#       'href': 'https://api.spotify.com/v1/artists/5aygfDCEaX5KTZOxSCpT9o',
#       'id': '5aygfDCEaX5KTZOxSCpT9o',
#       'name': 'Albert King',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aygfDCEaX5KTZOxSCpT9o'}],
#     'disc_number': 1,
#     'duration_ms': 239160,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFI87900038'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1VFoA9FU8IXhMKFYuFDCsp'},
#     'href': 'https://api.spotify.com/v1/tracks/1VFoA9FU8IXhMKFYuFDCsp',
#     'id': '1VFoA9FU8IXhMKFYuFDCsp',
#     'is_local': False,
#     'is_playable': True,
#     'name': "I'll Play The Blues For You - Edit",
#     'popularity': 28,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1VFoA9FU8IXhMKFYuFDCsp'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aygfDCEaX5KTZOxSCpT9o'},
#        'href': 'https://api.spotify.com/v1/artists/5aygfDCEaX5KTZOxSCpT9o',
#        'id': '5aygfDCEaX5KTZOxSCpT9o',
#        'name': 'Albert King',
#        'type': 'artist',
#        'uri': 'spotify:artist:5aygfDCEaX5KTZOxSCpT9o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3kBahttJGSWR3pAmkGm6OR'},
#      'href': 'https://api.spotify.com/v1/albums/3kBahttJGSWR3pAmkGm6OR',
#      'id': '3kBahttJGSWR3pAmkGm6OR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/e8a44a14dad0d80260ee8b7c74deed53621b2bce',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/1d796dbed508c99db699731469ec97cb8c21721b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/64522489940be1fe2d32dcd2a8371346408137fb',
#        'width': 64}],
#      'name': 'Roadhouse Blues',
#      'release_date': '2013-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:3kBahttJGSWR3pAmkGm6OR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aygfDCEaX5KTZOxSCpT9o'},
#       'href': 'https://api.spotify.com/v1/artists/5aygfDCEaX5KTZOxSCpT9o',
#       'id': '5aygfDCEaX5KTZOxSCpT9o',
#       'name': 'Albert King',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aygfDCEaX5KTZOxSCpT9o'}],
#     'disc_number': 1,
#     'duration_ms': 608120,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFI88800261'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3pDzW4JyPj8Lz2h2BswAJO'},
#     'href': 'https://api.spotify.com/v1/tracks/3pDzW4JyPj8Lz2h2BswAJO',
#     'id': '3pDzW4JyPj8Lz2h2BswAJO',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Roadhouse Blues - Live',
#     'popularity': 25,
#     'preview_url': None,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:3pDzW4JyPj8Lz2h2BswAJO'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=roadhouse+blues&type=track&market=US&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 719}}
