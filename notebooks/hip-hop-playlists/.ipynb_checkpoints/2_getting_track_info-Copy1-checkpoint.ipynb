# %%
# %matplotlib inline

# %%
import spotipy
from credentials import client_id, client_secret
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
from datetime import datetime

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

scope = 'user-library-read' #this came from the tutorial ¯\_(ツ)_/¯
user = '125065858' #had to get this from the spotify desktop app

include = [
    'Hip-Hop: 1994 - 1999',
    'Hip-Hop: 2000 - 2006',
    'Hip-Hop: 2007 - 2014'
]

# %%
# generate the arrays first

playlists = sp.user_playlists(user)
arr = []

while playlists:
    
    for i, playlist in enumerate(playlists['items']):
        if playlist['name'] in include:
            print(playlist['name'])
            playlist_length = 0
            
            playlist_id, playlist_name, playlist_uri = playlist['id'], playlist['name'], playlist['uri']

            tracks = sp.user_playlist_tracks(user=user,playlist_id=playlist_id)
            tracklist = tracks['items']
            for track in tracklist:
                track_info = track['track']
                track_id, track_name, track_popularity, track_uri, added_on = track_info['id'], track_info['name'], track_info['popularity'], track_info['uri'], track['added_at']
                artists = [i['name'] for i in track['track']['artists']]
                track_artist = artists[0]
                if len(artists) > 1:
                    featured_artists = ', '.join(artists[1:])
                else:
                    featured_artists = ''
                playlist_length += 1
                print('Song count:', playlist_length, end='\r')

                
                track_arr = [playlist_id, playlist_name, playlist_uri, track_id, track_name, track_artist, featured_artists, track_popularity, track_uri, added_on]
                #feature_arr = list(sp.audio_features(tracks=['2uPc8UjfmiuzmAJj3VBs8N'])[0].values()) #this takes too long!
                arr.append(track_arr)# + feature_arr)

            print()
            
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None

df = pd.DataFrame(arr,columns=['playlist_id', 'playlist_name', 'playlist_uri', 'track_id', 'track_name', 'track_artist', 'featured_artists', 'track_popularity', 'track_uri', 'added_on'])

# either write data to file line by line within loops, or take all arrays, stuff them into a dataframe, and write to csv
counter = 0
for track_id in df['track_id']:
    counter += 1
    d = sp.audio_features(tracks=[track_id])[0]
    for i in d:
        print(len(df)-counter,'of',len(df),'remaining |',end='\r')
        df.loc[df['track_id'] == d['id'],i] = d[i]        

df['time_added'] = [datetime.strptime(dt,'%Y-%m-%dT%H:%M:%SZ').time() for dt in df['added_on']]
df['date_added'] = [datetime.strptime(dt,'%Y-%m-%dT%H:%M:%SZ').date() for dt in df['added_on']]
df['hour_added'] = [datetime.strptime(dt,'%Y-%m-%dT%H:%M:%SZ').hour for dt in df['added_on']]
df['day_added'] = [datetime.strptime(dt,'%Y-%m-%dT%H:%M:%SZ').isoweekday() for dt in df['added_on']]
df['month_added'] = [datetime.strptime(dt,'%Y-%m-%dT%H:%M:%SZ').month for dt in df['added_on']]        
        
df.to_csv('HH-spotify_playlist_info.csv',index=False)
# Out:
# Hip-Hop: 1994 - 1999
# Song count: 44
# Hip-Hop: 2000 - 2006
# Song count: 100
# Hip-Hop: 2007 - 2014
# Song count: 97
# 0 of 241 remaining |||

# %% [markdown]
# ---

# %%
df = pd.read_csv('HH-spotify_playlist_info.csv')

# %%
df.columns
# Out:
# Index(['playlist_id', 'playlist_name', 'playlist_uri', 'track_id',
#        'track_name', 'track_artist', 'featured_artists', 'track_popularity',
#        'track_uri', 'added_on', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df.head()
# Out:
#               playlist_id         playlist_name  \
# 0  7f89DdKO9vRrn7nl5Gjhdq  Hip-Hop: 1994 - 1999
# 1  7f89DdKO9vRrn7nl5Gjhdq  Hip-Hop: 1994 - 1999
# 2  7f89DdKO9vRrn7nl5Gjhdq  Hip-Hop: 1994 - 1999
# 3  7f89DdKO9vRrn7nl5Gjhdq  Hip-Hop: 1994 - 1999
# 4  7f89DdKO9vRrn7nl5Gjhdq  Hip-Hop: 1994 - 1999
#
#                               playlist_uri                track_id  \
# 0  spotify:playlist:7f89DdKO9vRrn7nl5Gjhdq  22uZ8sPzkovoQG4Cu39Pqe
# 1  spotify:playlist:7f89DdKO9vRrn7nl5Gjhdq  5Tl0HJvynZtKdSUMKbFVVX
# 2  spotify:playlist:7f89DdKO9vRrn7nl5Gjhdq  5MnXRG5LzgSzdpIkg5nagT
# 3  spotify:playlist:7f89DdKO9vRrn7nl5Gjhdq  1FkgoPdajl8gwC1hlyvHtC
# 4  spotify:playlist:7f89DdKO9vRrn7nl5Gjhdq  4LGMSdeKOUoy5Wf75Je0Hl
#
#                               track_name track_artist featured_artists  \
# 0                            Big Pimpin'        JAY Z              UGK
# 1        Hard Knock Life (Ghetto Anthem)        JAY Z
# 2  Nigga What, Nigga Who (Originator 99)        JAY Z          Big Jaz
# 3                      Money, Cash, Hoes        JAY Z              DMX
# 4                         Can I Get A...        JAY Z    Amil, Ja Rule
#
#    track_popularity                             track_uri  \
# 0                 0  spotify:track:22uZ8sPzkovoQG4Cu39Pqe
# 1                 5  spotify:track:5Tl0HJvynZtKdSUMKbFVVX
# 2                 0  spotify:track:5MnXRG5LzgSzdpIkg5nagT
# 3                 0  spotify:track:1FkgoPdajl8gwC1hlyvHtC
# 4                 2  spotify:track:4LGMSdeKOUoy5Wf75Je0Hl
#
#                added_on  ...  liveness  valence    tempo            type  \
# 0  2016-12-31T05:45:38Z  ...    0.0406    0.914  138.030  audio_features
# 1  2016-12-31T05:46:05Z  ...    0.0285    0.557   77.030  audio_features
# 2  2016-12-31T05:46:11Z  ...    0.0656    0.714  132.916  audio_features
# 3  2016-12-31T05:46:15Z  ...    0.1890    0.476   90.073  audio_features
# 4  2016-12-31T05:46:19Z  ...    0.1020    0.825   88.557  audio_features
#
#                        id                                   uri  \
# 0  22uZ8sPzkovoQG4Cu39Pqe  spotify:track:22uZ8sPzkovoQG4Cu39Pqe
# 1  5Tl0HJvynZtKdSUMKbFVVX  spotify:track:5Tl0HJvynZtKdSUMKbFVVX
# 2  5MnXRG5LzgSzdpIkg5nagT  spotify:track:5MnXRG5LzgSzdpIkg5nagT
# 3  1FkgoPdajl8gwC1hlyvHtC  spotify:track:1FkgoPdajl8gwC1hlyvHtC
# 4  4LGMSdeKOUoy5Wf75Je0Hl  spotify:track:4LGMSdeKOUoy5Wf75Je0Hl
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/22uZ8sPzkovo...
# 1  https://api.spotify.com/v1/tracks/5Tl0HJvynZtK...
# 2  https://api.spotify.com/v1/tracks/5MnXRG5LzgSz...
# 3  https://api.spotify.com/v1/tracks/1FkgoPdajl8g...
# 4  https://api.spotify.com/v1/tracks/4LGMSdeKOUoy...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/22uZ...     284640.0
# 1  https://api.spotify.com/v1/audio-analysis/5Tl0...     238467.0
# 2  https://api.spotify.com/v1/audio-analysis/5MnX...     233173.0
# 3  https://api.spotify.com/v1/audio-analysis/1Fkg...     286133.0
# 4  https://api.spotify.com/v1/audio-analysis/4LGM...     309773.0
#
#    time_signature
# 0             4.0
# 1             4.0
# 2             4.0
# 3             4.0
# 4             4.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Analysis
# ---

# %%
df.sort_values(by='added_on',ascending=True).plot(
    y='liveness',x='added_on',
    kind='line',
    figsize=(20,5)
)

# %% [markdown]
# # How many tracks are added during different parts of the day?
# ---

# %%
df.groupby('hour_added').count().reset_index().plot(y='id',x='hour_added',figsize=(20,5),kind='bar',rot=0)

# %% [markdown]
# # All features over time:
# ---

# %%
features = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness','acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

# %%
for feature in features:
    df.plot(y=feature,x='date_added',rot=90,figsize=(15,5),kind='line')

# %% [markdown]
# # By Hour Added
# ---

# %%
for feature in features:
    df.plot(y=feature,x='hour_added',rot=90,figsize=(20,5),kind='scatter',alpha=.075,c='lightskyblue',s=75)

# %% [markdown]
# Energy has an interesting trend:

# %%
df.groupby('hour_added').mean().plot(
    y=['instrumentalness','energy','speechiness'], #luckily these all use the same y axis
    kind='line',
    figsize=(20,5),
    xticks=df['hour_added']
) # this is coffee.

# %% [markdown]
# # By Day Added
#
# Less days in the week than hours in a day, so there is more overlap of values (so a smaller marker size is used)
#
# ---

# %%
df.groupby('day_added').sum().plot(
    y=['instrumentalness','energy','speechiness'], #luckily these all use the same y axis
    kind='line',
    figsize=(20,5),
    xticks=df['day_added'],
    title='Sum, by Day of Week Added'
) # this is coffee.

df.groupby('day_added').mean().plot(
    y=['instrumentalness','energy','speechiness'], #luckily these all use the same y axis
    kind='line',
    figsize=(20,5),
    xticks=df['day_added'],
    title='Average, by Day of Week Added'
) # this is coffee.

# %%
for feature in features:
    df.plot(y=feature,x='day_added',rot=90,figsize=(20,5),kind='scatter',alpha=.05,c='lightskyblue',s=75)

# %% [markdown]
# ---

# %% [markdown]
# What are the songs added after 10AM?

# %%
df[(df['hour_added'] >= 11) & (df['hour_added'] <= 13)].head()
# Out:
#                 playlist_id         playlist_name  \
# 129  3y49fFPdrFmUasnATCd6uH  Hip-Hop: 2000 - 2006
# 130  3y49fFPdrFmUasnATCd6uH  Hip-Hop: 2000 - 2006
# 131  3y49fFPdrFmUasnATCd6uH  Hip-Hop: 2000 - 2006
# 132  3y49fFPdrFmUasnATCd6uH  Hip-Hop: 2000 - 2006
# 133  3y49fFPdrFmUasnATCd6uH  Hip-Hop: 2000 - 2006
#
#                                 playlist_uri                track_id  \
# 129  spotify:playlist:3y49fFPdrFmUasnATCd6uH  6CN3e26iQSj1N5lomh0mfO
# 130  spotify:playlist:3y49fFPdrFmUasnATCd6uH  4JNTpbntShpUpACDUzwHV5
# 131  spotify:playlist:3y49fFPdrFmUasnATCd6uH  6ug1aF09BMclmvs4XCPG5D
# 132  spotify:playlist:3y49fFPdrFmUasnATCd6uH  5GO4rpfnM2lghVqEulTJUf
# 133  spotify:playlist:3y49fFPdrFmUasnATCd6uH  1eFuyVf8I77imXbGAtJfvF
#
#                   track_name                             track_uri  \
# 129        Like Toy Soldiers  spotify:track:6CN3e26iQSj1N5lomh0mfO
# 130                      GO!  spotify:track:4JNTpbntShpUpACDUzwHV5
# 131  So High - Cloud 9 Remix  spotify:track:6ug1aF09BMclmvs4XCPG5D
# 132                 They Say  spotify:track:5GO4rpfnM2lghVqEulTJUf
# 133    Certified feat. Bilal  spotify:track:1eFuyVf8I77imXbGAtJfvF
#
#                  added_on  danceability  energy   key  ...  \
# 129  2017-02-09T11:01:31Z         0.671   0.755   1.0  ...
# 130  2017-02-09T12:03:08Z         0.842   0.775  10.0  ...
# 131  2017-02-09T12:04:46Z         0.582   0.818   5.0  ...
# 132  2017-02-09T12:08:14Z         0.715   0.701  11.0  ...
# 133  2017-02-09T12:16:32Z         0.705   0.734   0.0  ...
#
#                                       uri  \
# 129  spotify:track:6CN3e26iQSj1N5lomh0mfO
# 130  spotify:track:4JNTpbntShpUpACDUzwHV5
# 131  spotify:track:6ug1aF09BMclmvs4XCPG5D
# 132  spotify:track:5GO4rpfnM2lghVqEulTJUf
# 133  spotify:track:1eFuyVf8I77imXbGAtJfvF
#
#                                             track_href  \
# 129  https://api.spotify.com/v1/tracks/6CN3e26iQSj1...
# 130  https://api.spotify.com/v1/tracks/4JNTpbntShpU...
# 131  https://api.spotify.com/v1/tracks/6ug1aF09BMcl...
# 132  https://api.spotify.com/v1/tracks/5GO4rpfnM2lg...
# 133  https://api.spotify.com/v1/tracks/1eFuyVf8I77i...
#
#                                           analysis_url  duration_ms  \
# 129  https://api.spotify.com/v1/audio-analysis/6CN3...     296880.0
# 130  https://api.spotify.com/v1/audio-analysis/4JNT...     224160.0
# 131  https://api.spotify.com/v1/audio-analysis/6ug1...     307280.0
# 132  https://api.spotify.com/v1/audio-analysis/5GO4...     237040.0
# 133  https://api.spotify.com/v1/audio-analysis/1eFu...     280893.0
#
#      time_signature  time_added  date_added  hour_added day_added month_added
# 129             4.0    11:01:31  2017-02-09          11         4           2
# 130             4.0    12:03:08  2017-02-09          12         4           2
# 131             4.0    12:04:46  2017-02-09          12         4           2
# 132             4.0    12:08:14  2017-02-09          12         4           2
# 133             5.0    12:16:32  2017-02-09          12         4           2
#
# [5 rows x 30 columns]

# %% [markdown]
# # Takeaways
#
# ---
# - Does Spotify use time-based features in their recommendation systems?
